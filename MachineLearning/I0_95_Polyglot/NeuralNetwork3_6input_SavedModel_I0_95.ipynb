# %%
import tensorflow.keras.backend as K
from tensorflow.keras.models import load_model

# re-define your custom activation exactly as before
def radbas(x):
    return K.exp(-K.square(x))

# load the .keras file
model5_matlab = load_model('model5_matlab.keras',
                         custom_objects={'radbas': radbas})

# %%
import pandas as pd

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[26],
    'p1':[28.2203],
    'L2':[93],
    'p2':[-19.6979] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.42

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[27.58],
    'p1':[28.3983],
    'L2':[94],
    'p2':[-19.319] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.90

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[24.68],
    'p1':[28.8508],
    'L2':[-147],
    'p2':[-17.8748] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 117.05

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[24.68],
    'p1':[28.3938],
    'L2':[-222],
    'p2':[-19.2065] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 117.30

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.68],
    'p1':[28.3102],
    'L2':[93],
    'p2':[-19.7319] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.37

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.31],
    'p1':[28.3615],
    'L2':[94],
    'p2':[-19.779] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.19

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.12],
    'p1':[28.2761],
    'L2':[94],
    'p2':[-19.7317] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.18

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.94],
    'p1':[28.2221],
    'L2':[93],
    'p2':[-19.7254] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.40

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.54],
    'p1':[28.3338],
    'L2':[94],
    'p2':[-19.7303] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.20

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.34],
    'p1':[28.3311],
    'L2':[94],
    'p2':[-19.7284] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.19

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[25.15],
    'p1':[28.2872],
    'L2':[-758],
    'p2':[-19.6692] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 117.29

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[26],
    'p1':[28.2203],
    'L2':[93],
    'p2':[-19.6979] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.42

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[18],
    'p1':[27.4982],
    'L2':[92],
    'p2':[-21.8195] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 113.03

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[21],
    'p1':[27.5339],
    'L2':[93],
    'p2':[-20.8219] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.43

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[19],
    'p1':[27.4387],
    'L2':[93],
    'p2':[-21.2978] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.70

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5715],
    'L2':[93],
    'p2':[-21.0979] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.00

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5355],
    'L2':[93],
    'p2':[-21.1581] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.04

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5489],
    'L2':[93],
    'p2':[-21.1385] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.03

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5766],
    'L2':[93],
    'p2':[-21.1756] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.06

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5479],
    'L2':[93],
    'p2':[-21.1298] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.02

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5489],
    'L2':[93],
    'p2':[-21.1541] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.04

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5484],
    'L2':[93],
    'p2':[-21.1421] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.03

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5777],
    'L2':[93],
    'p2':[-21.1743] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.06

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5327],
    'L2':[93],
    'p2':[-21.1206] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.01

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5727],
    'L2':[93],
    'p2':[-21.1845] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.07

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5481],
    'L2':[93],
    'p2':[-21.1266] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.02

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.574],
    'L2':[93],
    'p2':[-21.1815] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.06

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.582],
    'L2':[93],
    'p2':[-21.1539] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.04

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5798],
    'L2':[93],
    'p2':[-21.1686] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.05

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5334],
    'L2':[93],
    'p2':[-21.1234] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.02

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[20],
    'p1':[27.5481],
    'L2':[93],
    'p2':[-21.1555] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.04

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[26],
    'p1':[28.2203],
    'L2':[85],
    'p2':[26.0546] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 116.43

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[26],
    'p1':[28.2203],
    'L2':[93],
    'p2':[-19.6979] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.42

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [65],
    'L1':[26],
    'p1':[28.2203],
    'L2':[93],
    'p2':[-17.8729] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.59

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[26],
    'p1':[28.2203],
    'L2':[93],
    'p2':[-20.9192] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.29

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[20],
    'p1':[27.2779],
    'L2':[91],
    'p2':[-22.7806] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 111.49

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[23],
    'p1':[27.5365],
    'L2':[92],
    'p2':[-21.731] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.74

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[21],
    'p1':[27.5349],
    'L2':[92],
    'p2':[-22.321] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.38

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5824],
    'L2':[92],
    'p2':[-22.0381] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.91

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[21],
    'p1':[27.4777],
    'L2':[93],
    'p2':[-22.1973] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.10

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.531],
    'L2':[92],
    'p2':[-22.0589] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.92

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[21],
    'p1':[27.4596],
    'L2':[93],
    'p2':[-22.1857] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.09

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5287],
    'L2':[92],
    'p2':[-22.0654] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.93

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.4593],
    'L2':[92],
    'p2':[-22.1817] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.02

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5392],
    'L2':[92],
    'p2':[-22.1158] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.97

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.4985],
    'L2':[92],
    'p2':[-22.1527] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.00

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5194],
    'L2':[92],
    'p2':[-22.0839] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.94

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.4748],
    'L2':[92],
    'p2':[-22.1705] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.01

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5247],
    'L2':[92],
    'p2':[-22.0736] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.94

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.481],
    'L2':[92],
    'p2':[-22.142] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.99

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5157],
    'L2':[92],
    'p2':[-22.0899] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.95

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.4795],
    'L2':[92],
    'p2':[-22.167] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.01

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5313],
    'L2':[92],
    'p2':[-22.1235] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.98

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [70],
    'L1':[22],
    'p1':[27.5096],
    'L2':[92],
    'p2':[-22.1137] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 109.97

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [35],
    'L1':[26],
    'p1':[28.2203],
    'L2':[93],
    'p2':[-17.8729] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 106.35

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [35],
    'L1':[15],
    'p1':[27.5178],
    'L2':[94],
    'p2':[-17.8954] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.58

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [35],
    'L1':[15],
    'p1':[27.5124],
    'L2':[94],
    'p2':[-17.8957] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.58

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [35],
    'L1':[15],
    'p1':[27.5121],
    'L2':[94],
    'p2':[-17.8957] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 110.58

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[26],
    'p1':[28.2203],
    'L2':[85],
    'p2':[26.0546] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 117.67

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[2],
    'p1':[27.4359],
    'L2':[94],
    'p2':[-18.6997] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 165.60

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[16],
    'p1':[27.5114],
    'L2':[94],
    'p2':[-17.8682] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 769ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 167.35

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[15],
    'p1':[27.5776],
    'L2':[94],
    'p2':[-17.8948] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 164.41

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[15],
    'p1':[27.5128],
    'L2':[94],
    'p2':[-17.8957] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 164.36

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[26],
    'p1':[28.2203],
    'L2':[85],
    'p2':[26.0546] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 117.67

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[92],
    'p1':[-19.2548],
    'L2':[73],
    'p2':[-23.6474] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 147.30

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[15],
    'p1':[27.5121],
    'L2':[94],
    'p2':[-17.8957] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 164.36

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [125],
    'L1':[107],
    'p1':[29.0351],
    'L2':[-81],
    'p2':[28.2203] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 140.34

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[34],
    'p1':[-17.8305],
    'L2':[62],
    'p2':[-21.2705] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 122.04

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [35],
    'L1':[34],
    'p1':[-17.8305],
    'L2':[70],
    'p2':[-22.8803] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 97.81

# %%
new_input = pd.DataFrame({
    'Amp': [12],
    'L': [95],
    'L1':[84],
    'p1':[28.9585],
    'L2':[-82],
    'p2':[28.8248] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 140.34

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[20],
    'p1':[27.5761],
    'L2':[91],
    'p2':[26.0789] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 137.48

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[88],
    'p1':[27.69],
    'L2':[93],
    'p2':[-17.9063] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 139.70

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[15],
    'p1':[27.377],
    'L2':[90],
    'p2':[26.715] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 144.38

# %%
new_input = pd.DataFrame({
    'Amp': [3],
    'L': [95],
    'L1':[25],
    'p1':[-23.4945],
    'L2':[70],
    'p2':[-24.3134] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 158.29

# %%
new_input = pd.DataFrame({
    'Amp': [3],
    'L': [95],
    'L1':[12],
    'p1':[-23.5844],
    'L2':[74],
    'p2':[-24.302] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 147.01

# %%
new_input = pd.DataFrame({
    'Amp': [3],
    'L': [95],
    'L1':[12],
    'p1':[-23.5837],
    'L2':[74],
    'p2':[-24.3015] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 147.01

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[34],
    'p1':[-17.8305],
    'L2':[62],
    'p2':[-21.2705] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 122.04

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[20],
    'p1':[27.5761],
    'L2':[91],
    'p2':[26.0789] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 137.48

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[34],
    'p1':[-17.8305],
    'L2':[62],
    'p2':[-21.2705] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 122.04

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[111.04],
    'p1':[39.5328],
    'L2':[96],
    'p2':[-17.9007] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 139.78

# %%
new_input = pd.DataFrame({
    'Amp': [6],
    'L': [95],
    'L1':[9],
    'p1':[40.3914],
    'L2':[96],
    'p2':[26.9659] 
})
prediction_new = model5_matlab.predict(new_input.values)
print("4 Layer NN - Prediction with 6 inputs - tnext: {:.2f}".format(prediction_new[0][0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 4 Layer NN - Prediction with 6 inputs - tnext: 151.07
